# %%
#python assignment 3 question1.1 myreduce
def myreduce(add,list_1):
    return a
def add(a,b):
    return a+b
list_1=[10,15,25,40,10]
a=list_1[0]
for i in range(1,len(list_1)):
    b=list_1[i]
    a=add(a,b)
print(myreduce(add,list_1))
# Out:
# 100

# %%
#python assignment 3 question1.1 myfilter
def is_even(a):
    if a%2==0:
        return True
list_1=[2,3,4,5,6,7,8,9,12345,5678,890,1234,567]
list(filter(is_even,list_1))
# Out:
# [2, 4, 6, 8, 5678, 890, 1234]
